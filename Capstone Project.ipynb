# %% [markdown]
# #  Capstone Project Notebook: Battle of Neighbourhoods

# %% [markdown]
# # Author: Kumbirai Theotimus Chinyanga

# %% [markdown]
# ## Description: In this project we will use machine learning models to investigate neighbourhoods using location data from FOURSQUARE.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Hello Capstone Project Course
